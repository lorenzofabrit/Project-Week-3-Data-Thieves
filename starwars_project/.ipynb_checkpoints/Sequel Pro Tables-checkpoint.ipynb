# %%
import pandas as pd

# %%
characters = pd.read_csv('../csv/characters.csv')

# %%
df = pd.DataFrame(characters)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 10 columns):
# name          87 non-null object
# height        81 non-null float64
# mass          59 non-null object
# hair_color    81 non-null object
# skin_color    85 non-null object
# eye_color     84 non-null object
# birth_year    43 non-null object
# gender        84 non-null object
# homeworld     77 non-null object
# species       82 non-null object
# dtypes: float64(1), object(9)
# memory usage: 6.9+ KB

# %%
df[['name','mass','hair_color','skin_color','eye_color','birth_year','gender','homeworld','species']].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 9 columns):
# name          87 non-null object
# mass          87 non-null object
# hair_color    87 non-null object
# skin_color    87 non-null object
# eye_color     87 non-null object
# birth_year    87 non-null object
# gender        87 non-null object
# homeworld     87 non-null object
# species       87 non-null object
# dtypes: object(9)
# memory usage: 6.2+ KB

# %%
def to_sql(df, characters, ):
    df.to_sql(table_name, self.conn, if_exists=ifexists)

# %%
from DBConnector import DBConnector
ifexists='replace'

# %%
from sqlalchemy import create_engine

# %%
driver   = 'mysql+pymysql:'
user     = 'root'
password = '<new-password>'
ip       = '127.0.0.1'
database = 'Starwars'

# %%
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
print(connection_string)
# Out:
# mysql+pymysql://root:<new-password>@127.0.0.1/Starwars

# %%
engine = create_engine(connection_string)
print(engine)
# Out:
# Engine(mysql+pymysql://root:***@127.0.0.1/Starwars)

# %%
data = pd.read_csv('characters.csv')
df = pd.DataFrame(data)
df.to_sql('characters', con=engine, if_exists='replace',index_label='id')

# %%
data = pd.read_csv('planets.csv')
df = pd.DataFrame(data)
df.to_sql('planets', con=engine, if_exists='replace',index_label='id')

# %%
data = pd.read_csv('species.csv')
df = pd.DataFrame(data)
df.to_sql('species', con=engine, if_exists='replace',index_label='id')

# %%
data = pd.read_csv('starships.csv')
df = pd.DataFrame(data)
df.to_sql('starships', con=engine, if_exists='replace',index_label='id')

# %%
data = pd.read_csv('vehicles.csv')
df = pd.DataFrame(data)
df.to_sql('vehicles', con=engine, if_exists='replace',index_label='id')

# %% [markdown]
# ## Speediest Starship

# %%
df_speed = df.drop(columns=['cost_in_credits', 'length', 'consumables'])
df
# Out:
#                              name                                     model  \
# 0                        Executor           Executor-class star dreadnought
# 1    Sentinel-class landing craft              Sentinel-class landing craft
# 2                      Death Star               DS-1 Orbital Battle Station
# 3               Millennium Falcon                   YT-1300 light freighter
# 4                          Y-wing                                BTL Y-wing
# 5                          X-wing                               T-65 X-wing
# 6                 TIE Advanced x1               Twin Ion Engine Advanced x1
# 7                         Slave 1      Firespray-31-class patrol and attack
# 8                Imperial shuttle                 Lambda-class T-4a shuttle
# 9   EF76 Nebulon-B escort frigate             EF76 Nebulon-B escort frigate
# 10               Calamari Cruiser            MC80 Liberty type Star Cruiser
# ...

# %%
df_speed.sort_values(by = 'MGLT', ascending=False)
# Out:
#                              name                                     model  \
# 11                         A-wing                   RZ-1 A-wing Interceptor
# 6                 TIE Advanced x1               Twin Ion Engine Advanced x1
# 32                        arc-170  Aggressive Reconnaissance-170 starfighte
# 5                          X-wing                               T-65 X-wing
# 12                         B-wing                A/SF-01 B-wing starfighter
# 4                          Y-wing                                BTL Y-wing
# 3               Millennium Falcon                   YT-1300 light freighter
# 7                         Slave 1      Firespray-31-class patrol and attack
# 1    Sentinel-class landing craft              Sentinel-class landing craft
# 35                  CR90 corvette                             CR90 corvette
# 21                 Star Destroyer           Imperial I-class Star Destroyer
# ...

# %%
df_speed.sort_values(by = 'max_atmosphering_speed', ascending=False)
# Out:
#                              name                                     model  \
# 29        Republic attack cruiser              Senator-class Star Destroyer
# 21                 Star Destroyer           Imperial I-class Star Destroyer
# 35                  CR90 corvette                             CR90 corvette
# 12                         B-wing                A/SF-01 B-wing starfighter
# 15           Naboo Royal Starship          J-type 327 Nubian royal starship
# 13               Republic Cruiser                    Consular-class cruiser
# 8                Imperial shuttle                 Lambda-class T-4a shuttle
# 20            H-type Nubian yacht                       H-type Nubian yacht
# 9   EF76 Nebulon-B escort frigate             EF76 Nebulon-B escort frigate
# 25                Rebel transport                    GR-75 medium transport
# 23       Theta-class T-2c shuttle                  Theta-class T-2c shuttle
# ...

# %%
df_speed.sort_values(by = 'hyperdrive_rating', ascending=False)
# Out:
#                              name                                     model  \
# 33       Belbullab-22 starfighter                  Belbullab-22 starfighter
# 2                      Death Star               DS-1 Orbital Battle Station
# 25                Rebel transport                    GR-75 medium transport
# 7                         Slave 1      Firespray-31-class patrol and attack
# 0                        Executor           Executor-class star dreadnought
# 13               Republic Cruiser                    Consular-class cruiser
# 35                  CR90 corvette                             CR90 corvette
# 9   EF76 Nebulon-B escort frigate             EF76 Nebulon-B escort frigate
# 21                 Star Destroyer           Imperial I-class Star Destroyer
# 26             Droid control ship        Lucrehulk-class Droid Control Ship
# 12                         B-wing                A/SF-01 B-wing starfighter
# ...

# %% [markdown]
# ## Most sensible starship

# %%
df['people_capacity'] = df['crew'] + df['passengers']

# %%
df['cost_per_person'] = df['cost_in_credits'] / df['people_capacity']

# %%
df
# Out:
#                              name                                     model  \
# 0                        Executor           Executor-class star dreadnought
# 1    Sentinel-class landing craft              Sentinel-class landing craft
# 2                      Death Star               DS-1 Orbital Battle Station
# 3               Millennium Falcon                   YT-1300 light freighter
# 4                          Y-wing                                BTL Y-wing
# 5                          X-wing                               T-65 X-wing
# 6                 TIE Advanced x1               Twin Ion Engine Advanced x1
# 7                         Slave 1      Firespray-31-class patrol and attack
# 8                Imperial shuttle                 Lambda-class T-4a shuttle
# 9   EF76 Nebulon-B escort frigate             EF76 Nebulon-B escort frigate
# 10               Calamari Cruiser            MC80 Liberty type Star Cruiser
# ...

# %%
df.sort_values(by = 'cost_per_person')
# Out:
#                              name                                     model  \
# 28                   Solar Sailer    Punworcca 116-class interstellar sloop
# 22       Trade Federation cruiser        Providence-class carrier/destroyer
# 1    Sentinel-class landing craft              Sentinel-class landing craft
# 21                 Star Destroyer           Imperial I-class Star Destroyer
# 0                        Executor           Executor-class star dreadnought
# 35                  CR90 corvette                             CR90 corvette
# 29        Republic attack cruiser              Senator-class Star Destroyer
# 9   EF76 Nebulon-B escort frigate             EF76 Nebulon-B escort frigate
# 8                Imperial shuttle                 Lambda-class T-4a shuttle
# 3               Millennium Falcon                   YT-1300 light freighter
# 10               Calamari Cruiser            MC80 Liberty type Star Cruiser
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 15 columns):
# name                      37 non-null object
# model                     37 non-null object
# manufacturer              37 non-null object
# cost_in_credits           26 non-null float64
# length                    36 non-null object
# max_atmosphering_speed    29 non-null object
# crew                      36 non-null float64
# passengers                33 non-null float64
# cargo_capacity            29 non-null float64
# consumables               31 non-null object
# hyperdrive_rating         35 non-null float64
# MGLT                      17 non-null float64
# starship_class            37 non-null object
# people_capacity           32 non-null float64
# cost_per_person           25 non-null float64
# dtypes: float64(8), object(7)
# memory usage: 4.5+ KB

# %%
df
# Out:
#                              name                                     model  \
# 0                        Executor           Executor-class star dreadnought
# 1    Sentinel-class landing craft              Sentinel-class landing craft
# 2                      Death Star               DS-1 Orbital Battle Station
# 3               Millennium Falcon                   YT-1300 light freighter
# 4                          Y-wing                                BTL Y-wing
# 5                          X-wing                               T-65 X-wing
# 6                 TIE Advanced x1               Twin Ion Engine Advanced x1
# 7                         Slave 1      Firespray-31-class patrol and attack
# 8                Imperial shuttle                 Lambda-class T-4a shuttle
# 9   EF76 Nebulon-B escort frigate             EF76 Nebulon-B escort frigate
# 10               Calamari Cruiser            MC80 Liberty type Star Cruiser
# ...

# %%
df_clean = df[~df.manufacturer.str.match("Kuat")]

# %%
df1 = df_clean[~df_clean.name.str.match("Republic")]

# %%
df2 = df1[~df1.name.str.match("Imperial")]

# %%
df3 = df2[~df2.name.str.match("fighter")]

# %%
df4 = df3[~df3.name.str.match("Rebel")]

# %%
df5 = df4[~df4.name.str.match("Death")]

# %%
df6 = df5[~df5.name.str.match("Death")]

# %%
df6.to_csv('sensiblest')

# %%
df6.sort_values(by = 'cost_per_person')
# Out:
#                             name                                     model  \
# 28                  Solar Sailer    Punworcca 116-class interstellar sloop
# 22      Trade Federation cruiser        Providence-class carrier/destroyer
# 1   Sentinel-class landing craft              Sentinel-class landing craft
# 35                 CR90 corvette                             CR90 corvette
# 3              Millennium Falcon                   YT-1300 light freighter
# 10              Calamari Cruiser            MC80 Liberty type Star Cruiser
# 23      Theta-class T-2c shuttle                  Theta-class T-2c shuttle
# 32                       arc-170  Aggressive Reconnaissance-170 starfighte
# 4                         Y-wing                                BTL Y-wing
# 17       J-type diplomatic barge                   J-type diplomatic barge
# 5                         X-wing                               T-65 X-wing
# ...

# %%
df.to_csv('sensible')

# %%
pwd
# Out:
# '/Users/home/Ironhack/Week_4/2/Project-Week-3-Data-Thieves/csv'
